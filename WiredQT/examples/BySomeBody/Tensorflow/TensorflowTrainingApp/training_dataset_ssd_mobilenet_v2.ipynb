# %%
#line 1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#line 2
# %cd '/content/drive/My Drive/Colab Notebooks'
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git clone https://github.com/tensorflow/models.git

# %%
#line 4
# %cd '/content/drive/My Drive/Colab Notebooks/models/research'
# Out:
# /content/drive/My Drive/Colab Notebooks/models/research

# %%
#line 5
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .

# %%
# !python object_detection/builders/model_builder_tf2_test.py

# %%
#line 9
# %cd '/content/drive/My Drive/Colab Notebooks/models/research/object_detection'
# Out:
# /content/drive/My Drive/Colab Notebooks/models/research/object_detection

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
# Out:
# --2021-06-03 21:24:04--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.195.128, 2607:f8b0:400e:c09::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.195.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20518283 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.57M  45.1MB/s    in 0.4s
#
# 2021-06-03 21:24:05 (45.1 MB/s) - ‘ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz’ saved [20518283/20518283]

# %%
# !tar xvf ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8.tar.gz
# Out:
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_640x640_coco17_tpu-8/saved_model/variables/variables.index

# %%
#line 12
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.5.0

# %%
#line 13 
#if tensorflow is 
# !pip install tensorflow==2.5

# %%
# !git clone https://github.com/armaanpriyadarshan/Training-a-Custom-TensorFlow-2.X-Object-Detector.git

# %%
# %cd 'Training-a-Custom-TensorFlow-2.X-Object-Detector/workspace/training_demo'
# Out:
# /content/drive/My Drive/Colab Notebooks/models/research/object_detection/Training-a-Custom-TensorFlow-2.X-Object-Detector/workspace/training_demo

# %%
# !python3 model_main_tf2.py --model_dir=models/my_ssd_mobilenet_v2_fpnlite --pipeline_config_path=models/my_ssd_mobilenet_v2_fpnlite/pipeline.config
# Out:
# INFO:tensorflow:Step 100 per-step time 9.517s
# I0603 22:08:17.867737 139844285122432 model_lib_v2.py:699] Step 100 per-step time 9.517s
# INFO:tensorflow:{'Loss/classification_loss': 0.3036326,
#  'Loss/localization_loss': 0.24330929,
#  'Loss/regularization_loss': 0.15200831,
#  'Loss/total_loss': 0.6989502,
#  'learning_rate': 0.0319994}
# I0603 22:08:17.868126 139844285122432 model_lib_v2.py:700] {'Loss/classification_loss': 0.3036326,
#  'Loss/localization_loss': 0.24330929,
#  'Loss/regularization_loss': 0.15200831,
#  'Loss/total_loss': 0.6989502,
#  'learning_rate': 0.0319994}

# %%
tensorboard --logdir=models\my_ssd_mobilenet_v2_fpnlite

# %%
#line 15
# !python3 ./exporter_main_v2.py --input_type image_tensor --pipeline_config_path ./models/my_ssd_mobilenet_v2_fpnlite/pipeline.config --trained_checkpoint_dir ./models/my_ssd_mobilenet_v2_fpnlite/ --output_directory ./exported-models/my_mobilenet_model

# %%
#line 16
