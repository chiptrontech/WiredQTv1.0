# %%
#line 1
from google.colab import drive
drive.mount('/content/drive')

# %%
#line 2# for training we will use ver 1.15, for object detection we will use vesion 2.0 
#please restart runtime after installation of tensorflow under Runtime->Restart runtime
# !pip install tensorflow==1.15

# %%
#line 3
# %cd '/content/drive/My Drive/Colab Notebooks'

# %%
#line 4
# !git clone https://github.com/tensorflow/models.git

# %%
#line 5
# %cd '/content/drive/My Drive/Colab Notebooks/models/research'

# %%
#line 6
# !protoc object_detection/protos/*.proto --python_out=.

# %%
#line 7
# !cp object_detection/packages/tf2/setup.py .

# %%
#line 8
# !python setup.py build
# !python setup.py install

# %%
#line 8
# %cd '/content/drive/My Drive/Colab Notebooks/models/research/slim'

# %%
#line 9 nothing to execute here

# %%
#line 10
# !python setup.py build
# !python setup.py install

# %%
#line 11
# %cd '/content/drive/My Drive/Colab Notebooks/models/research/object_detection'

# %%
#line 12 skip if already done before
# !wget http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz

# %%
#line 13 skip if already done before
# !tar xvf faster_rcnn_inception_v2_coco_2018_01_28.tar.gz

# %%
#line 14
#check readme(Paste file and folder to object_detection) after paste, give at least 20 sec before executing this line
# !python3 train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config

# %%
#line 15
# !python show_training_index.py

# %%
#line 16

# %%
#copy frozen_inference_graph.pb under inference_graph folder of your google drive
#copy labelmap.pbtxt under training folder of your google drive
